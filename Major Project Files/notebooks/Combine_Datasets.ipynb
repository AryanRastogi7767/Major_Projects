# %%
import pandas as pd

# %%
#CHECKING FILE SHAPE
import pandas as pd
import os

# Get list of CSV files in the current directory
csv_files = [f for f in os.listdir('.') if f.endswith('.csv')]

# Loop through each CSV file and read into a DataFrame
for file in csv_files:
    df = pd.read_csv(file)
    print(df.columns)
    print(f"Shape of {file}: {df.shape}")
# Out:
# Index(['Unnamed: 0', 'count', 'hate_speech', 'offensive_language', 'neither',
#        'class', 'tweet'],
#       dtype='object')
# Shape of davidson_data.csv: (24783, 7)
# Index(['entities', 'created_at', 'text', 'edit_history_tweet_ids',
#        'public_metrics', 'id'],
#       dtype='object')
# Shape of hasoc_offn.csv: (131, 6)
# Index(['edit_history_tweet_ids', 'text', 'public_metrics', 'created_at', 'id',
#        'entities', 'geo'],
#       dtype='object')
# Shape of hasoc_hate.csv: (58, 7)
# Index(['entities', 'id', 'edit_history_tweet_ids', 'created_at', 'text',
#        'public_metrics', 'geo'],
#       dtype='object')
# Shape of aristotle_hate.csv: (1614, 7)
# Index(['id', 'geo', 'edit_history_tweet_ids', 'text', 'entities',
#        'public_metrics', 'created_at'],
#       dtype='object')
# Shape of copenhagen_hate.csv: (2684, 7)
# ---------------------------------------------------------------------------
# ...

# %%
#IMPORTING ALL DOWNLOADED DATASETS

copen = pd.read_csv("copenhagen_hate.csv")
aris = pd.read_csv('aristotle_hate.csv')
david = pd.read_csv('davidson_data.csv')
georgia = pd.read_csv('georgiatech_hate.csv')
hasoc1 = pd.read_csv('hasoc_hate.csv')
hasoc2= pd.read_csv("hasoc_offn.csv")

# %%
copen.shape
# Out:
# (2684, 7)

# %%
aris.shape
# Out:
# (1614, 7)

# %%
georgia.shape
# Out:
# (14991, 8)

# %%
georgia
# Out:
#                         id                                               text  \
# 0      1240976182494908416  Fuck the ding dongs. Fuck the ching chongs. An...
# 1      1238239331879464960  Fuck china fuck China fuck China\nFuck China f...
# 2      1241749496821772289  Yes! #China #CCP are 100% responsible #FuckChi...
# 3      1248071608738013184  #FuckChina #ChinaMustPay #CCPVirus #XijinpingV...
# 4      1243622953587068928  @DrJacobsRad #FuckChina #CCP #China - the real...
# ...                    ...                                                ...
# 14986  1241478818361008128  @brhodes Chinese state media even called it th...
# 14987  1243409849720786944  @VoiceOfAxom @realDonaldTrump CCP is the virus...
# 14988  1250603359523897345  @SenTomCotton Chinese communist Party should c...
# 14989  1250444997171740674  @AP Never trust the Communists. The Chinese co...
# 14990  1244912140160401408  @Michael_Yon #WuhanVirus pandemic shows that C...
#
# ...

# %%
hasoc1.shape
# Out:
# (58, 7)

# %%
hasoc2.shape
# Out:
# (131, 6)

# %%
add the target column in all the datasets and clean the dataframes to get text only then concatenate
# Out:
#                       id                                                geo  \
# 0     572341498827522049  {'coordinates': {'type': 'Point', 'coordinates...
# 1     572340476503724032                                                NaN
# 2     572334712804384768                                                NaN
# 3     572332655397629952                                                NaN
# 4     446460991396917248                                                NaN
# ...                  ...                                                ...
# 2679  569990621315919872                                                NaN
# 2680  570244879265206272                                                NaN
# 2681  571013698111860736                                                NaN
# 2682  571304517930774528                                                NaN
# 2683  575664315627216896                                                NaN
#
#       edit_history_tweet_ids  \
# ...

# %% [markdown]
# ##SELECTING TWEET AND TARGET COLUMNS FROM THE DATASETS

# %%
david.columns
# Out:
# Index(['Unnamed: 0', 'count', 'hate_speech', 'offensive_language', 'neither',
#        'class', 'tweet'],
#       dtype='object')

# %%
david = david.rename(columns={"class":"target"})

# %%
david[david['target'] == 1]['tweet']
# Out:
# 1        !!!!! RT @mleew17: boy dats cold...tyga dwn ba...
# 2        !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...
# 3        !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...
# 4        !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...
# 5        !!!!!!!!!!!!!!!!!!"@T_Madison_x: The shit just...
#                                ...
# 24774    you really care bout dis bitch. my dick all in...
# 24775     you worried bout other bitches, you need me for?
# 24778    you's a muthaf***in lie &#8220;@LifeAsKing: @2...
# 24780    young buck wanna eat!!.. dat nigguh like I ain...
# 24781                youu got wild bitches tellin you lies
# Name: tweet, Length: 19190, dtype: object

# %%
david['target'] = david['target'].replace([2],1)
david['target'].value_counts()
# Out:
# 1    23353
# 0     1430
# Name: target, dtype: int64

# %%
david =david.replace([0,1],[1,0])

# %%
david['target'].value_counts()
# Out:
# 0    23353
# 1     1430
# Name: target, dtype: int64

# %%
david = david[['tweet','target']]

# %%
david
# Out:
#                                                    tweet  target
# 0      !!! RT @mayasolovely: As a woman you shouldn't...       0
# 1      !!!!! RT @mleew17: boy dats cold...tyga dwn ba...       0
# 2      !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...       0
# 3      !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...       0
# 4      !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...       0
# ...                                                  ...     ...
# 24778  you's a muthaf***in lie &#8220;@LifeAsKing: @2...       0
# 24779  you've gone and broke the wrong heart baby, an...       0
# 24780  young buck wanna eat!!.. dat nigguh like I ain...       0
# 24781              youu got wild bitches tellin you lies       0
# 24782  ~~Ruffled | Ntac Eileen Dahlia - Beautiful col...       0
#
# [24783 rows x 2 columns]

# %%
aris = aris.rename(columns = {'text':"tweet"})

# %%
aris['target'] = 1

# %%
aris
# Out:
#                                                entities                  id  \
# 0     {'annotations': [{'start': 7, 'end': 14, 'prob...  850433664890544128
# 1     {'mentions': [{'start': 3, 'end': 14, 'usernam...  850100742035836929
# 2                                                   NaN  847804507367100416
# 3     {'mentions': [{'start': 0, 'end': 10, 'usernam...  850090319165050880
# 4     {'mentions': [{'start': 3, 'end': 12, 'usernam...  848686686930382848
# ...                                                 ...                 ...
# 1609  {'hashtags': [{'start': 98, 'end': 113, 'tag':...  850701219568001025
# 1610  {'hashtags': [{'start': 0, 'end': 18, 'tag': '...  849316180670259205
# 1611  {'urls': [{'start': 85, 'end': 108, 'url': 'ht...  849674709763358720
# 1612  {'hashtags': [{'start': 53, 'end': 66, 'tag': ...  849246676854484992
# 1613  {'urls': [{'start': 121, 'end': 144, 'url': 'h...  849635522389651456
#
# ...

# %%
aris = aris[['tweet','target']]

# %%
aris
# Out:
#                                                   tweet  target
# 0     I hate er chase because if the Bitch that work...       1
# 1     RT @nyctophil3: Pineapples do not belong on pi...       1
# 2     Niggas keep talking about women wearing weave ...       1
# 3     @vappywave idiot that's not gonna work. you go...       1
# 4     RT @ayevonnn: bruh i fucking hate people like ...       1
# ...                                                 ...     ...
# 1609  Baekhyun won 'Most Popular Artist of Korea'\n\...       1
# 1610  #TripleTalaqArrest 2fgt dis social menace #Tri...       1
# 1611  White nationalists' latest tactic to recruit c...       1
# 1612  We are in a comfortable lead fight against gal...       1
# 1613  Took him less than a minute...!! Gutless grub!...       1
#
# [1614 rows x 2 columns]

# %%
copen = copen.rename(columns={"text":"tweet"})
copen['target'] = 1
copen = copen[['tweet','target']]

# %%
copen
# Out:
#                                                   tweet  target
# 0     Drasko they didn't cook half a bird you idiot ...       1
# 1     Hopefully someone cooks Drasko in the next ep ...       1
# 2     of course you were born in serbia...you're as ...       1
# 3     These girls are the equivalent of the irritati...       1
# 4     RT @YesYoureRacist: At least you're only a tin...       1
# ...                                                 ...     ...
# 2679  RT @Superjutah: @MT8_9 £34,000 is £9000 above ...       1
# 2680  RT @DufresneFrank: “@gabystama: @DufresneFrank...       1
# 2681  RT @BoycottBrandy: @ActionFlickDoc this person...       1
# 2682  RT @Lyall: Patriarchy™ will expel me if I divu...       1
# 2683  RT @AsheSchow: Women’s Studies: Learn how to t...       1
#
# [2684 rows x 2 columns]

# %%
georgia = georgia.rename(columns={"text":"tweet"})
georgia['target'] = 1
georgia = georgia[['tweet','target']]
georgia
# Out:
#                                                    tweet  target
# 0      Fuck the ding dongs. Fuck the ching chongs. An...       1
# 1      Fuck china fuck China fuck China\nFuck China f...       1
# 2      Yes! #China #CCP are 100% responsible #FuckChi...       1
# 3      #FuckChina #ChinaMustPay #CCPVirus #XijinpingV...       1
# 4      @DrJacobsRad #FuckChina #CCP #China - the real...       1
# ...                                                  ...     ...
# 14986  @brhodes Chinese state media even called it th...       1
# 14987  @VoiceOfAxom @realDonaldTrump CCP is the virus...       1
# 14988  @SenTomCotton Chinese communist Party should c...       1
# 14989  @AP Never trust the Communists. The Chinese co...       1
# 14990  @Michael_Yon #WuhanVirus pandemic shows that C...       1
#
# [14991 rows x 2 columns]

# %%
georgia = georgia[:1000]

# %%
georgia
# Out:
#                                                  tweet  target
# 0    Fuck the ding dongs. Fuck the ching chongs. An...       1
# 1    Fuck china fuck China fuck China\nFuck China f...       1
# 2    Yes! #China #CCP are 100% responsible #FuckChi...       1
# 3    #FuckChina #ChinaMustPay #CCPVirus #XijinpingV...       1
# 4    @DrJacobsRad #FuckChina #CCP #China - the real...       1
# ..                                                 ...     ...
# 995  China bans eating wild animals https://t.co/l5...       1
# 996  @tymajestic Good that the Wuhan wet market has...       1
# 997  @OptimusPorpoise Good that the Wuhan wet marke...       1
# 998  @spectatorindex World should bicoott china for...       1
# 999  @Echinanews The Chinese Communist Party &amp; ...       1
#
# [1000 rows x 2 columns]

# %%
hasoc1 = hasoc1.rename(columns={"text":"tweet"})
hasoc1['target'] = 1
hasoc1 = hasoc1[['tweet','target']]
hasoc1
# Out:
#                                                 tweet  target
# 0   RT @SmStains007: Modi will never again represe...       1
# 1   RT @marleygonarley: My bitch a backwood ur bit...       1
# 2   RT @Lubchansky: good to know rich people have ...       1
# 3   @realDonaldTrump No, most Americans think you ...       1
# 4   RT @BrennenTaylor: Beauty gurus are so problem...       1
# 5   RT @ruinthesteele: billie eilish is a 17 year ...       1
# 6   The Senate President, Bukola Saraki, Deputy Se...       1
# 7   RT @AdamantxYves: America is just a series of ...       1
# 8   Never will you ever see another series where t...       1
# 9   RT @TheTunnelingCat: #TransCrowdFund Hey all I...       1
# 10  And if you find a Filipina, and she’s fine, yo...       1
# 11                       WHAT THE FUCK #GameOfThrones       1
# 12             Fuck your book https://t.co/vyq2jBM9M1       1
# 13  Attorney General Barr cancels second day of te...       1
# ...

# %%
hasoc2 = hasoc2.rename(columns={"text":"tweet"})
hasoc2['target'] = 1
hasoc2 = hasoc2[['tweet','target']]
hasoc2
# Out:
#                                                  tweet  target
# 0    Nobody:\nAngie: U getting dick ? Cus ur ass lo...       1
# 1                 Shame on you https://t.co/jVKBTvjKw9       1
# 2    RT @charliekirk11: I am so SICK of Republicans...       1
# 3    @RealSaavedra @benshapiro My hot water heater ...       1
# 4    All I hear is my siblings coming in the house....       1
# ..                                                 ...     ...
# 126  RT @causticbob: are you a racist? https://t.co...       1
# 127  @NRLonNine @wwos @Channel9 If cronulla played ...       1
# 128  RT @songadaymann: this is a song comprised ent...       1
# 129  @realDonaldTrump Yup. Give it a rest you nut j...       1
# 130  @funder Keep smiling @LindseyGrahamSC you trum...       1
#
# [131 rows x 2 columns]

# %% [markdown]
# ##COMBINING AND SAVING THE PROCESSED DATASET

# %%
data = pd.concat([copen, aris, georgia, hasoc1, hasoc2, david])

# %%
data['target'].value_counts()
# Out:
# 0    23353
# 1     6917
# Name: target, dtype: int64

# %%
data.to_csv("combined_data2.csv", index=False)
